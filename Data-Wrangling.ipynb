# %%
import pandas as pd
import numpy as np
import nltk
nltk.download('wordnet')
import string
import re
import fasttext
import contractions
import matplotlib.pyplot as plt
from bs4 import BeautifulSoup
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords, wordnet
from nltk.stem import WordNetLemmatizer
import sys
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Cisco\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
tweets = pd.read_csv('covidvaccine.csv')

# %%
tweets.shape
# Out:
# (38459, 13)

# %%
#Checks out what type of data we're working with.

tweets.dtypes
# Out:
# user_name           object
# user_location       object
# user_description    object
# user_created        object
# user_followers       int64
# user_friends         int64
# user_favourites      int64
# user_verified         bool
# date                object
# text                object
# hashtags            object
# source              object
# is_retweet            bool
# dtype: object

# %%
# Checks out what columns have null values.

for col in tweets.columns:
    print(col,tweets[col].isnull().sum())
# Out:
# user_name 0
# user_location 8443
# user_description 2373
# user_created 0
# user_followers 0
# user_friends 0
# user_favourites 0
# user_verified 0
# date 0
# text 0
# hashtags 11621
# source 1
# is_retweet 0

# %%
#Filters data, so the results have are on topic to what this analysis is looking for.

search_Keywords = ['vaccine','vaccines', 'covid-19', 'covid', 'cure','cures', 'corona','virus' 'coronavirus', '#covidvaccine','#coronavaccine'
                  '#coronavirusvaccine','#covid-19','#vaccine','#covid19vaccine']
filter_tweets_by_keywords = tweets['text'].apply(lambda x: len(set(search_Keywords) - set(x.lower().split()))) < len(search_Keywords)
tweets_filtered = tweets[filter_tweets_by_keywords].reset_index()

# %%
#Deletes an unnecessary column for our analysis.

del tweets_filtered['is_retweet']

# %%
tweets_filtered.shape
# Out:
# (24526, 13)

# %%
#Remove any contractions within the 'text' column.
#Then we recombine the elements within the 'no_contractions' column into a string.

tweets_filtered['no_contractions'] = tweets_filtered['text'].apply(lambda x: [contractions.fix(word) for word in x.split()])
tweets_filtered['text_str'] = [' '.join(map(str, l)) for l in tweets_filtered['no_contractions']]
tweets_filtered.head()
# Out:
#    index                                    user_name  \
# 0      0                                     MyNewsNE
# 1      1                                Shubham Gupta
# 2      2                      Journal of Infectiology
# 3      7  AKisASocialisolationist wash yer damn hands
# 4      9                                     VUMC OAP
#
#                  user_location  \
# 0                        Assam
# 1                          NaN
# 2                          NaN
# 3  The Great Pacific Northwest
# 4                Nashville, TN
#
#                                     user_description      user_created  \
# 0  MyNewsNE a dedicated multi-lingual media house...  24-05-2020 10:18
# 1  I will tell about all experiences of my life f...  14-08-2020 16:42
# 2  Journal of Infectiology (ISSN 2689-9981) is ac...  14-12-2017 07:07
# 3  Iconoclast, cat person, soccer fan, textile & ...  07-02-2015 07:24
# 4  Office of Advanced Practice, Vanderbilt Univer...  16-03-2017 20:22
#
#    user_followers  user_friends  user_favourites  user_verified  \
# 0              64            11              110          False
# 1               1            17                0          False
# 2             143           566                8          False
# 3            2321          3236           264351          False
# 4             282            96              788          False
#
#                date                                               text  \
# 0  18-08-2020 12:55  Australia to Manufacture Covid-19 Vaccine and ...
# 1  18-08-2020 12:55  #CoronavirusVaccine #CoronaVaccine #CovidVacci...
# 2  18-08-2020 12:46  Deaths due to COVID-19 in Affected Countries\n...
# 3  18-08-2020 12:30  @MSNBC Well, let’s qualify that: would anyone ...
# 4  18-08-2020 11:57  #DNA  zooms up charts in 1st week; hear #vacci...
#
#                                             hashtags               source  \
# 0                                   ['CovidVaccine']      Twitter Web App
# 1  ['CoronavirusVaccine', 'CoronaVaccine', 'Covid...  Twitter for Android
# 2                                                NaN      Twitter Web App
# 3                                   ['CovidVaccine']   Twitter for iPhone
# 4  ['DNA', 'vaccines', 'pandemic', 'COVID19', 'Co...      Twitter Web App
#
#                                      no_contractions  \
# 0  [Australia, to, Manufacture, Covid-19, Vaccine...
# 1  [#CoronavirusVaccine, #CoronaVaccine, #CovidVa...
# 2  [Deaths, due, to, COVID-19, in, Affected, Coun...
# 3  [@MSNBC, Well,, let us, qualify, that:, would,...
# 4  [#DNA, zooms, up, charts, in, 1st, week;, hear...
#
#                                             text_str
# 0  Australia to Manufacture Covid-19 Vaccine and ...
# 1  #CoronavirusVaccine #CoronaVaccine #CovidVacci...
# 2  Deaths due to COVID-19 in Affected Countries R...
# 3  @MSNBC Well, let us qualify that: would anyone...
# 4  #DNA zooms up charts in 1st week; hear #vaccin...

# %%
#Tokenize the words in each of the tweets & lowercase all its elements.

tweets_filtered['tokenized'] = tweets_filtered['text_str'].apply(word_tokenize)
tweets_filtered['low_tokenized'] = tweets_filtered.text.str.lower()
tweets_filtered.head()
# Out:
#    index                                    user_name  \
# 0      0                                     MyNewsNE
# 1      1                                Shubham Gupta
# 2      2                      Journal of Infectiology
# 3      7  AKisASocialisolationist wash yer damn hands
# 4      9                                     VUMC OAP
#
#                  user_location  \
# 0                        Assam
# 1                          NaN
# 2                          NaN
# 3  The Great Pacific Northwest
# 4                Nashville, TN
#
#                                     user_description      user_created  \
# 0  MyNewsNE a dedicated multi-lingual media house...  24-05-2020 10:18
# 1  I will tell about all experiences of my life f...  14-08-2020 16:42
# 2  Journal of Infectiology (ISSN 2689-9981) is ac...  14-12-2017 07:07
# 3  Iconoclast, cat person, soccer fan, textile & ...  07-02-2015 07:24
# 4  Office of Advanced Practice, Vanderbilt Univer...  16-03-2017 20:22
#
#    user_followers  user_friends  user_favourites  user_verified  \
# 0              64            11              110          False
# 1               1            17                0          False
# 2             143           566                8          False
# 3            2321          3236           264351          False
# 4             282            96              788          False
#
#                date                                               text  \
# 0  18-08-2020 12:55  Australia to Manufacture Covid-19 Vaccine and ...
# 1  18-08-2020 12:55  #CoronavirusVaccine #CoronaVaccine #CovidVacci...
# 2  18-08-2020 12:46  Deaths due to COVID-19 in Affected Countries\n...
# 3  18-08-2020 12:30  @MSNBC Well, let’s qualify that: would anyone ...
# 4  18-08-2020 11:57  #DNA  zooms up charts in 1st week; hear #vacci...
#
#                                             hashtags               source  \
# 0                                   ['CovidVaccine']      Twitter Web App
# 1  ['CoronavirusVaccine', 'CoronaVaccine', 'Covid...  Twitter for Android
# 2                                                NaN      Twitter Web App
# 3                                   ['CovidVaccine']   Twitter for iPhone
# 4  ['DNA', 'vaccines', 'pandemic', 'COVID19', 'Co...      Twitter Web App
#
#                                      no_contractions  \
# 0  [Australia, to, Manufacture, Covid-19, Vaccine...
# 1  [#CoronavirusVaccine, #CoronaVaccine, #CovidVa...
# 2  [Deaths, due, to, COVID-19, in, Affected, Coun...
# 3  [@MSNBC, Well,, let us, qualify, that:, would,...
# 4  [#DNA, zooms, up, charts, in, 1st, week;, hear...
#
#                                             text_str  \
# 0  Australia to Manufacture Covid-19 Vaccine and ...
# 1  #CoronavirusVaccine #CoronaVaccine #CovidVacci...
# 2  Deaths due to COVID-19 in Affected Countries R...
# 3  @MSNBC Well, let us qualify that: would anyone...
# 4  #DNA zooms up charts in 1st week; hear #vaccin...
#
#                                            tokenized  \
# 0  [Australia, to, Manufacture, Covid-19, Vaccine...
# 1  [#, CoronavirusVaccine, #, CoronaVaccine, #, C...
# 2  [Deaths, due, to, COVID-19, in, Affected, Coun...
# 3  [@, MSNBC, Well, ,, let, us, qualify, that, :,...
# 4  [#, DNA, zooms, up, charts, in, 1st, week, ;, ...
#
#                                        low_tokenized
# 0  australia to manufacture covid-19 vaccine and ...
# 1  #coronavirusvaccine #coronavaccine #covidvacci...
# 2  deaths due to covid-19 in affected countries\n...
# 3  @msnbc well, let’s qualify that: would anyone ...
# 4  #dna  zooms up charts in 1st week; hear #vacci...

# %%
#Here we'll remove the punctiation.

p = re.compile(r'[^\w\s]+')
tweets_filtered['no_punct'] = [p.sub('', x) for x in tweets_filtered['low_tokenized'].tolist()]

# %%
#Removes any stopwords from out data.

stop_words = set(stopwords.words('english'))
tweets_filtered['stopwords_rem'] = tweets_filtered['no_punct'].apply(lambda x: [word for word in x.split() if word not in stop_words])
tweets_filtered.head()
# Out:
#    index                                    user_name  \
# 0      0                                     MyNewsNE
# 1      1                                Shubham Gupta
# 2      2                      Journal of Infectiology
# 3      7  AKisASocialisolationist wash yer damn hands
# 4      9                                     VUMC OAP
#
#                  user_location  \
# 0                        Assam
# 1                          NaN
# 2                          NaN
# 3  The Great Pacific Northwest
# 4                Nashville, TN
#
#                                     user_description      user_created  \
# 0  MyNewsNE a dedicated multi-lingual media house...  24-05-2020 10:18
# 1  I will tell about all experiences of my life f...  14-08-2020 16:42
# 2  Journal of Infectiology (ISSN 2689-9981) is ac...  14-12-2017 07:07
# 3  Iconoclast, cat person, soccer fan, textile & ...  07-02-2015 07:24
# 4  Office of Advanced Practice, Vanderbilt Univer...  16-03-2017 20:22
#
#    user_followers  user_friends  user_favourites  user_verified  \
# 0              64            11              110          False
# 1               1            17                0          False
# 2             143           566                8          False
# 3            2321          3236           264351          False
# 4             282            96              788          False
#
#                date                                               text  \
# 0  18-08-2020 12:55  Australia to Manufacture Covid-19 Vaccine and ...
# 1  18-08-2020 12:55  #CoronavirusVaccine #CoronaVaccine #CovidVacci...
# 2  18-08-2020 12:46  Deaths due to COVID-19 in Affected Countries\n...
# 3  18-08-2020 12:30  @MSNBC Well, let’s qualify that: would anyone ...
# 4  18-08-2020 11:57  #DNA  zooms up charts in 1st week; hear #vacci...
#
#                                             hashtags               source  \
# 0                                   ['CovidVaccine']      Twitter Web App
# 1  ['CoronavirusVaccine', 'CoronaVaccine', 'Covid...  Twitter for Android
# 2                                                NaN      Twitter Web App
# 3                                   ['CovidVaccine']   Twitter for iPhone
# 4  ['DNA', 'vaccines', 'pandemic', 'COVID19', 'Co...      Twitter Web App
#
#                                      no_contractions  \
# 0  [Australia, to, Manufacture, Covid-19, Vaccine...
# 1  [#CoronavirusVaccine, #CoronaVaccine, #CovidVa...
# 2  [Deaths, due, to, COVID-19, in, Affected, Coun...
# 3  [@MSNBC, Well,, let us, qualify, that:, would,...
# 4  [#DNA, zooms, up, charts, in, 1st, week;, hear...
#
#                                             text_str  \
# 0  Australia to Manufacture Covid-19 Vaccine and ...
# 1  #CoronavirusVaccine #CoronaVaccine #CovidVacci...
# 2  Deaths due to COVID-19 in Affected Countries R...
# 3  @MSNBC Well, let us qualify that: would anyone...
# 4  #DNA zooms up charts in 1st week; hear #vaccin...
#
#                                            tokenized  \
# 0  [Australia, to, Manufacture, Covid-19, Vaccine...
# 1  [#, CoronavirusVaccine, #, CoronaVaccine, #, C...
# 2  [Deaths, due, to, COVID-19, in, Affected, Coun...
# 3  [@, MSNBC, Well, ,, let, us, qualify, that, :,...
# 4  [#, DNA, zooms, up, charts, in, 1st, week, ;, ...
#
#                                        low_tokenized  \
# 0  australia to manufacture covid-19 vaccine and ...
# 1  #coronavirusvaccine #coronavaccine #covidvacci...
# 2  deaths due to covid-19 in affected countries\n...
# 3  @msnbc well, let’s qualify that: would anyone ...
# 4  #dna  zooms up charts in 1st week; hear #vacci...
#
#                                             no_punct  \
# 0  australia to manufacture covid19 vaccine and g...
# 1  coronavirusvaccine coronavaccine covidvaccine ...
# 2  deaths due to covid19 in affected countries\nr...
# 3  msnbc well lets qualify that would anyone of a...
# 4  dna  zooms up charts in 1st week hear vaccines...
#
#                                        stopwords_rem
# 0  [australia, manufacture, covid19, vaccine, giv...
# 1  [coronavirusvaccine, coronavaccine, covidvacci...
# 2  [deaths, due, covid19, affected, countries, re...
# 3  [msnbc, well, lets, qualify, would, anyone, pa...
# 4  [dna, zooms, charts, 1st, week, hear, vaccines...

# %%
#Identifies each word's part of speech.

tweets_filtered['pos_tags'] = tweets_filtered['stopwords_rem'].apply(nltk.tag.pos_tag)
tweets_filtered.head()
# Out:
#    index                                    user_name  \
# 0      0                                     MyNewsNE
# 1      1                                Shubham Gupta
# 2      2                      Journal of Infectiology
# 3      7  AKisASocialisolationist wash yer damn hands
# 4      9                                     VUMC OAP
#
#                  user_location  \
# 0                        Assam
# 1                          NaN
# 2                          NaN
# 3  The Great Pacific Northwest
# 4                Nashville, TN
#
#                                     user_description      user_created  \
# 0  MyNewsNE a dedicated multi-lingual media house...  24-05-2020 10:18
# 1  I will tell about all experiences of my life f...  14-08-2020 16:42
# 2  Journal of Infectiology (ISSN 2689-9981) is ac...  14-12-2017 07:07
# 3  Iconoclast, cat person, soccer fan, textile & ...  07-02-2015 07:24
# 4  Office of Advanced Practice, Vanderbilt Univer...  16-03-2017 20:22
#
#    user_followers  user_friends  user_favourites  user_verified  \
# 0              64            11              110          False
# 1               1            17                0          False
# 2             143           566                8          False
# 3            2321          3236           264351          False
# 4             282            96              788          False
#
#                date                                               text  \
# 0  18-08-2020 12:55  Australia to Manufacture Covid-19 Vaccine and ...
# 1  18-08-2020 12:55  #CoronavirusVaccine #CoronaVaccine #CovidVacci...
# 2  18-08-2020 12:46  Deaths due to COVID-19 in Affected Countries\n...
# 3  18-08-2020 12:30  @MSNBC Well, let’s qualify that: would anyone ...
# 4  18-08-2020 11:57  #DNA  zooms up charts in 1st week; hear #vacci...
#
#                                             hashtags               source  \
# 0                                   ['CovidVaccine']      Twitter Web App
# 1  ['CoronavirusVaccine', 'CoronaVaccine', 'Covid...  Twitter for Android
# 2                                                NaN      Twitter Web App
# 3                                   ['CovidVaccine']   Twitter for iPhone
# 4  ['DNA', 'vaccines', 'pandemic', 'COVID19', 'Co...      Twitter Web App
#
#                                      no_contractions  \
# 0  [Australia, to, Manufacture, Covid-19, Vaccine...
# 1  [#CoronavirusVaccine, #CoronaVaccine, #CovidVa...
# 2  [Deaths, due, to, COVID-19, in, Affected, Coun...
# 3  [@MSNBC, Well,, let us, qualify, that:, would,...
# 4  [#DNA, zooms, up, charts, in, 1st, week;, hear...
#
#                                             text_str  \
# 0  Australia to Manufacture Covid-19 Vaccine and ...
# 1  #CoronavirusVaccine #CoronaVaccine #CovidVacci...
# 2  Deaths due to COVID-19 in Affected Countries R...
# 3  @MSNBC Well, let us qualify that: would anyone...
# 4  #DNA zooms up charts in 1st week; hear #vaccin...
#
#                                            tokenized  \
# 0  [Australia, to, Manufacture, Covid-19, Vaccine...
# 1  [#, CoronavirusVaccine, #, CoronaVaccine, #, C...
# 2  [Deaths, due, to, COVID-19, in, Affected, Coun...
# 3  [@, MSNBC, Well, ,, let, us, qualify, that, :,...
# 4  [#, DNA, zooms, up, charts, in, 1st, week, ;, ...
#
#                                        low_tokenized  \
# 0  australia to manufacture covid-19 vaccine and ...
# 1  #coronavirusvaccine #coronavaccine #covidvacci...
# 2  deaths due to covid-19 in affected countries\n...
# 3  @msnbc well, let’s qualify that: would anyone ...
# 4  #dna  zooms up charts in 1st week; hear #vacci...
#
#                                             no_punct  \
# 0  australia to manufacture covid19 vaccine and g...
# 1  coronavirusvaccine coronavaccine covidvaccine ...
# 2  deaths due to covid19 in affected countries\nr...
# 3  msnbc well lets qualify that would anyone of a...
# 4  dna  zooms up charts in 1st week hear vaccines...
#
#                                        stopwords_rem  \
# 0  [australia, manufacture, covid19, vaccine, giv...
# 1  [coronavirusvaccine, coronavaccine, covidvacci...
# 2  [deaths, due, covid19, affected, countries, re...
# 3  [msnbc, well, lets, qualify, would, anyone, pa...
# 4  [dna, zooms, charts, 1st, week, hear, vaccines...
#
#                                             pos_tags
# 0  [(australia, JJ), (manufacture, NN), (covid19,...
# 1  [(coronavirusvaccine, NN), (coronavaccine, NN)...
# 2  [(deaths, NNS), (due, JJ), (covid19, RB), (aff...
# 3  [(msnbc, RB), (well, RB), (lets, VBZ), (qualif...
# 4  [(dna, NN), (zooms, NNS), (charts, NNS), (1st,...

# %%
#This will concise the part of speech tags from above (Is it accurate?).

def wordnet_pos(tag):
    if tag.startswith('J'):
        return wordnet.ADJ
    elif tag.startswith('V'):
        return wordnet.VERB
    elif tag.startswith('N'):
        return wordnet.NOUN
    elif tag.startswith('R'):
        return wordnet.ADV
    else:
        return wordnet.NOUN
    
tweets_filtered['wordnet_pos'] = tweets_filtered['pos_tags'].apply(lambda x: [(word, wordnet_pos(pos_tag)) for (word, pos_tag) in x])
tweets_filtered.head()
# Out:
#    index                                    user_name  \
# 0      0                                     MyNewsNE
# 1      1                                Shubham Gupta
# 2      2                      Journal of Infectiology
# 3      7  AKisASocialisolationist wash yer damn hands
# 4      9                                     VUMC OAP
#
#                  user_location  \
# 0                        Assam
# 1                          NaN
# 2                          NaN
# 3  The Great Pacific Northwest
# 4                Nashville, TN
#
#                                     user_description      user_created  \
# 0  MyNewsNE a dedicated multi-lingual media house...  24-05-2020 10:18
# 1  I will tell about all experiences of my life f...  14-08-2020 16:42
# 2  Journal of Infectiology (ISSN 2689-9981) is ac...  14-12-2017 07:07
# 3  Iconoclast, cat person, soccer fan, textile & ...  07-02-2015 07:24
# 4  Office of Advanced Practice, Vanderbilt Univer...  16-03-2017 20:22
#
#    user_followers  user_friends  user_favourites  user_verified  \
# 0              64            11              110          False
# 1               1            17                0          False
# 2             143           566                8          False
# 3            2321          3236           264351          False
# 4             282            96              788          False
#
#                date  ...                                           hashtags  \
# 0  18-08-2020 12:55  ...                                   ['CovidVaccine']
# 1  18-08-2020 12:55  ...  ['CoronavirusVaccine', 'CoronaVaccine', 'Covid...
# 2  18-08-2020 12:46  ...                                                NaN
# 3  18-08-2020 12:30  ...                                   ['CovidVaccine']
# 4  18-08-2020 11:57  ...  ['DNA', 'vaccines', 'pandemic', 'COVID19', 'Co...
#
#                 source                                    no_contractions  \
# 0      Twitter Web App  [Australia, to, Manufacture, Covid-19, Vaccine...
# 1  Twitter for Android  [#CoronavirusVaccine, #CoronaVaccine, #CovidVa...
# 2      Twitter Web App  [Deaths, due, to, COVID-19, in, Affected, Coun...
# 3   Twitter for iPhone  [@MSNBC, Well,, let us, qualify, that:, would,...
# 4      Twitter Web App  [#DNA, zooms, up, charts, in, 1st, week;, hear...
#
#                                             text_str  \
# 0  Australia to Manufacture Covid-19 Vaccine and ...
# 1  #CoronavirusVaccine #CoronaVaccine #CovidVacci...
# 2  Deaths due to COVID-19 in Affected Countries R...
# 3  @MSNBC Well, let us qualify that: would anyone...
# 4  #DNA zooms up charts in 1st week; hear #vaccin...
#
#                                            tokenized  \
# 0  [Australia, to, Manufacture, Covid-19, Vaccine...
# 1  [#, CoronavirusVaccine, #, CoronaVaccine, #, C...
# 2  [Deaths, due, to, COVID-19, in, Affected, Coun...
# 3  [@, MSNBC, Well, ,, let, us, qualify, that, :,...
# 4  [#, DNA, zooms, up, charts, in, 1st, week, ;, ...
#
#                                        low_tokenized  \
# 0  australia to manufacture covid-19 vaccine and ...
# 1  #coronavirusvaccine #coronavaccine #covidvacci...
# 2  deaths due to covid-19 in affected countries\n...
# 3  @msnbc well, let’s qualify that: would anyone ...
# 4  #dna  zooms up charts in 1st week; hear #vacci...
#
#                                             no_punct  \
# 0  australia to manufacture covid19 vaccine and g...
# 1  coronavirusvaccine coronavaccine covidvaccine ...
# 2  deaths due to covid19 in affected countries\nr...
# 3  msnbc well lets qualify that would anyone of a...
# 4  dna  zooms up charts in 1st week hear vaccines...
#
#                                        stopwords_rem  \
# 0  [australia, manufacture, covid19, vaccine, giv...
# 1  [coronavirusvaccine, coronavaccine, covidvacci...
# 2  [deaths, due, covid19, affected, countries, re...
# 3  [msnbc, well, lets, qualify, would, anyone, pa...
# 4  [dna, zooms, charts, 1st, week, hear, vaccines...
#
#                                             pos_tags  \
# 0  [(australia, JJ), (manufacture, NN), (covid19,...
# 1  [(coronavirusvaccine, NN), (coronavaccine, NN)...
# 2  [(deaths, NNS), (due, JJ), (covid19, RB), (aff...
# 3  [(msnbc, RB), (well, RB), (lets, VBZ), (qualif...
# 4  [(dna, NN), (zooms, NNS), (charts, NNS), (1st,...
#
#                                          wordnet_pos
# 0  [(australia, a), (manufacture, n), (covid19, n...
# 1  [(coronavirusvaccine, n), (coronavaccine, n), ...
# 2  [(deaths, n), (due, a), (covid19, r), (affecte...
# 3  [(msnbc, r), (well, r), (lets, v), (qualify, v...
# 4  [(dna, n), (zooms, n), (charts, n), (1st, n), ...
#
# [5 rows x 21 columns]

# %%
#Converts words into their root form. (didn't work for some - like 'affected' on index[2]).

word_Lemm = WordNetLemmatizer()
tweets_filtered['lemmatized'] = tweets_filtered['wordnet_pos'].apply(lambda x: [word_Lemm.lemmatize(word, tag) for word, tag in x])
tweets_filtered['lemmatized'].head(20)
# Out:
# 0     [australia, manufacture, covid19, vaccine, giv...
# 1     [coronavirusvaccine, coronavaccine, covidvacci...
# 2     [death, due, covid19, affected, country, read,...
# 3     [msnbc, well, let, qualify, would, anyone, par...
# 4     [dna, zoom, chart, 1st, week, hear, vaccine, e...
# 5     [covid19millionares, covid19, corona, covidvac...
# 6     [great, news, pfizers, vaccine, enter, phase, ...
# 7     [dangerous, yet, come, covidvaccine, corona, i...
# 8     [whole, narrative, covidvaccine, go, deathly, ...
# 9     [seruminstindia, look, raise, 1, billion, arou...
# 10    [global, vaccine, tracker, vaccine, covidvacci...
# 11    [coronavirus, update, american, businessman, t...
# 12    [search, chennai, corona, affect, street, area...
# 13    [vaccinate, world, vacine, vaccinate, coronavi...
# 14    [islamabad, pakistan, begin, phase, iii, clini...
# 15    [covid19, vocabulary, english, incubation, per...
# 16    [omg, expose, covid19, vaccine, ingredient, su...
# 17    [covidvaccine, 29, candidate, begin, trial, 6,...
# 18    [covid19, vocabulary, english, infectious, cli...
# 19    [phase, 3, trial, begin, next, 710, day, mean,...
# Name: lemmatized, dtype: object
